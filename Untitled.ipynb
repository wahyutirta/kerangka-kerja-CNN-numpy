# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
def load_train_details(**params):
    method = params.get("method", "adam")
    epochs = params.get("epochs", 500)
    batch = params.get("learningRate", 32)
    learningRate = params.get("batch", 0.01)
    mainPath = params.get("mainPath", "")
    stringName = str("-" + "jepun" + str(batch) + str(learningRate) + str(method) + str(epochs))

        
    fname = "valid_history" + str(stringName) + ".npz"
    path = os.path.join(mainPath,str(method),fname)
    arr_files = np.load(path)
    valid_loss_history, valid_acc_history, valid_steps = arr_files['arr_0'], arr_files['arr_1'], arr_files['arr_2']
    #print("validation====")
    #print(valid_loss_history.shape)
    #print(valid_acc_history.shape)
    #print(valid_steps.shape)
        
    fname = "step_history" + str(stringName) + ".npz"
    path = os.path.join(mainPath,str(method),fname)
    arr_files = np.load(path)
    loss_history, acc_history, weights_history, n_steps = arr_files['arr_0'], arr_files['arr_1'], arr_files['arr_2'], arr_files['arr_3']
    
    #print("step====")
    #print(loss_history.shape)
    #print(acc_history.shape)
    #print(weights_history.shape)
    #print(n_steps.shape)    
    
    fname = "epoch_history" + str(stringName) + ".npz"
    path = os.path.join(mainPath,str(method),fname)
    arr_files = np.load(path)
    epoch_loss, epoch_acc, epoch_weight, epochs = arr_files['arr_0'], arr_files['arr_1'], arr_files['arr_2'], arr_files['arr_3']
    #print("epoch====")
    #print(epoch_loss.shape)
    #print(epoch_acc.shape)
    #print(epoch_weight.shape)
    #print(epochs.shape)
    
    return valid_loss_history, valid_acc_history, valid_steps, loss_history, acc_history, weights_history, n_steps, epoch_loss, epoch_acc, epoch_weight

# %%
#mainPath = os.path.dirname(os.path.abspath(__file__)) #file path main.py
mainPath = globals()['_dh'][0]
workPath = os.path.split(mainPath) #path working folder (whole file project)
imagePath = "data_jepun"

method = "rmsprop"
epochs = 101
batch = 32
learningRate = 0.001

rms_valid_loss_history, rms_valid_acc_history, rms_valid_steps, rms_loss_history, rms_acc_history, rms_weights_history, rms_n_steps, rms_epoch_loss, rms_epoch_acc, rms_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

# %%
def plotting(epochs_array, array1, array2, tittle, label1, label2, y_label):
    plt.plot(epochs_array, array1, label = label1)

 
    plt.plot(epochs_array, array2, label = label2)
  
    # naming the x axis
    plt.xlabel('epochs')
    # naming the y axis
    plt.ylabel(y_label)
  
    # giving a title to my graph
    plt.title(tittle)

    # show a legend on the plot
    plt.legend()
  
    # function to show the plot
    plt.show()

# %%
label1 = "validation loss"
label2 = "average epoch loss"
tittle = "RMSprop Model Loss"
y_label = "loss"
plotting(epochs_array, rms_valid_loss_history, rms_epoch_loss, tittle ,label1, label2, y_label)

label1 = "validation acc"
label2 = "average epoch acc"
tittle = "RMSprop Model Accuracy"
plotting(epochs_array, rms_valid_acc_history, rms_epoch_acc, tittle ,label1, label2, y_label)

# %%
#mainPath = os.path.dirname(os.path.abspath(__file__)) #file path main.py
mainPath = globals()['_dh'][0]
workPath = os.path.split(mainPath) #path working folder (whole file project)
imagePath = "data_jepun"

method = "adam"
epochs = 101
batch = 32
learningRate = 0.001

adam_valid_loss_history, adam_valid_acc_history, adam_valid_steps, adam_loss_history, adam_acc_history, adam_weights_history, adam_n_steps, adam_epoch_loss, adam_epoch_acc, adam_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

# %%
label1 = "validation loss"
label2 = "average epoch loss"
tittle = "Adam Model Loss"
y_label = "loss"
plotting(epochs_array, adam_valid_loss_history, adam_epoch_loss, tittle ,label1, label2, y_label)

label1 = "validation acc"
label2 = "average epoch acc"
tittle = "Adam Model Accuracy"
y_label = "acc"
plotting(epochs_array, adam_valid_acc_history, adam_epoch_acc, tittle ,label1, label2, y_label)

# %%
label1 = "Adam Validation Loss"
label2 = "RMSprop Validation Loss"
tittle = "Optimizer Validation Loss"
y_label = "loss"
plotting(epochs_array, adam_valid_loss_history, rms_valid_loss_history, tittle ,label1, label2, y_label)

# %%
label1 = "Adam Validation Loss"
label2 = "RMSprop Validation Loss"
tittle = "Optimizer Validation Loss"
y_label = "loss"
plotting(epochs_array, adam_valid_loss_history, rms_valid_loss_history, tittle ,label1, label2, y_label)

label1 = "Adam Validation Acc"
label2 = "RMSprop Validation Acc"
tittle = "Optimizer Validation Acc"
y_label = "acc"
plotting(epochs_array, adam_valid_acc_history, rms_valid_acc_history, tittle ,label1, label2, y_label)

# %%
label1 = "Adam Epoch Loss"
label2 = "RMSprop Epoch Loss"
tittle = "Optimizer Epoch Loss"
y_label = "loss"
plotting(epochs_array, adam_epoch_loss, rms_epoch_loss, tittle ,label1, label2, y_label)

# %%
label1 = "Adam Epoch Loss"
label2 = "RMSprop Epoch Loss"
tittle = "Optimizer Epoch Loss"
y_label = "loss"
plotting(epochs_array, adam_epoch_loss, rms_epoch_loss, tittle ,label1, label2, y_label)

label1 = "Adam Epoch Acc"
label2 = "RMSprop Epoch Acc"
tittle = "Optimizer Epoch Acc"
y_label = "acc"
plotting(epochs_array, adam_epoch_acc, rms_epoch_acc, tittle ,label1, label2, y_label)

# %%
label1 = "Adam Epoch Weight"
label2 = "RMSprop Epoch Weight"
tittle = "Optimizer Epoch Weight"
y_label = "Weight"
plotting(epochs_array, adam_epoch_weight, rms_epoch_weight, tittle ,label1, label2, y_label)

# %%
print(adam_valid_acc_history)
# Out:
# [0.25   0.25   0.3    0.3125 0.325  0.3625 0.3125 0.3875 0.3375 0.325
#  0.3    0.2875 0.325  0.3125 0.375  0.3375 0.4    0.45   0.55   0.6125
#  0.7375 0.75   0.7875 0.625  0.775  0.775  0.825  0.725  0.8125 0.8
#  0.8625 0.8    0.875  0.7875 0.7625 0.85   0.8625 0.7625 0.7375 0.8
#  0.9    0.9125 0.825  0.8875 0.9    0.9125 0.9125 0.8625 0.9    0.8875
#  0.9125 0.9125 0.9125 0.9125 0.8625 0.9125 0.925  0.9125 0.9    0.9125
#  0.925  0.875  0.925  0.9125 0.875  0.925  0.9125 0.925  0.9    0.9375
#  0.8875 0.9    0.925  0.9125 0.9125 0.9125 0.9375 0.9375 0.9    0.9375
#  0.95   0.9375 0.9125 0.9375 0.9375 0.9375 0.925  0.9125 0.9375 0.9125
#  0.925  0.925  0.925  0.9375 0.9125 0.9375 0.9375 0.9375 0.925  0.9375
#  0.9375]

# %%
plt.plot(epochs_array, adam_valid_acc_history, label = "Adam Valid acc")
plt.plot(epochs_array, adam_epoch_acc, label = "Adam epoch acc")

plt.plot(epochs_array, rms_valid_acc_history, label = "Rms Valid acc")
plt.plot(epochs_array, rms_epoch_acc, label = "Rms epoch acc")
plt.xlabel('epochs')
# naming the y axis
plt.ylabel(y_label)
  
# giving a title to my graph
plt.title("epch 101")

# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %% [markdown]
# load last params

# %%
#mainPath = os.path.dirname(os.path.abspath(__file__)) #file path main.py
mainPath = globals()['_dh'][0]
workPath = os.path.split(mainPath) #path working folder (whole file project)
imagePath = "data_jepun"

method = "rmsprop"
epochs = 201
batch = 16
learningRate = 0.0001

valid_loss, valid_acc, valid_steps, loss_history, acc_history, weights_history, n_steps, epoch_loss, epoch_acc, epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

# %%
print("epoch loss", epoch_loss[-1])
print("validation loss", valid_loss[-1])
print("epoch acc",epoch_acc[-1])

print("validation acc", valid_acc[-1])
# Out:
# epoch loss 0.00023380819925935878
# validation loss 0.15623931959825904
# epoch acc 1.0
# validation acc 0.975

# %%
#mainPath = os.path.dirname(os.path.abspath(__file__)) #file path main.py
mainPath = globals()['_dh'][0]
workPath = os.path.split(mainPath) #path working folder (whole file project)
imagePath = "data_jepun"

method = "rmsprop"
epochs = 101
batch = 32
learningRate = 0.001

rmsa_valid_loss_history, rmsa_valid_acc_history, rmsa_valid_steps, rmsa_loss_history, rmsa_acc_history, rmsa_weights_history, rmsa_n_steps, rmsa_epoch_loss, rmsa_epoch_acc, rmsa_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

method = "adam"
epochs = 101
batch = 32
learningRate = 0.001

adama_valid_loss_history, adama_valid_acc_history, adama_valid_steps, adama_loss_history, adama_acc_history, adama_weights_history, adama_n_steps, adama_epoch_loss, adama_epoch_acc, adama_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

method = "rmsprop"
epochs = 101
batch = 32
learningRate = 0.0001

rmsb_valid_loss_history, rmsb_valid_acc_history, rmsb_valid_steps, rmsb_loss_history, rmsb_acc_history, rmsb_weights_history, rmsb_n_steps, rmsb_epoch_loss, rmsb_epoch_acc, rmsb_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

method = "adam"
epochs = 101
batch = 32
learningRate = 0.0001

adamb_valid_loss_history, adamb_valid_acc_history, adamb_valid_steps, adamb_loss_history, adamb_acc_history, adamb_weights_history, adamb_n_steps, adamb_epoch_loss, adamb_epoch_acc, adamb_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

method = "rmsprop"
epochs = 101
batch = 16
learningRate = 0.001

rmsc_valid_loss_history, rmsc_valid_acc_history, rmsc_valid_steps, rmsc_loss_history, rmsc_acc_history, rmsc_weights_history, rmsc_n_steps, rmsc_epoch_loss, rmsc_epoch_acc, rmsc_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

method = "adam"
epochs = 101
batch = 16
learningRate = 0.001

adamc_valid_loss_history, adamc_valid_acc_history, adamc_valid_steps, adamc_loss_history, adamc_acc_history, adamc_weights_history, adamc_n_steps, adamc_epoch_loss, adamc_epoch_acc, adamc_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

method = "rmsprop"
epochs = 101
batch = 16
learningRate = 0.0001

rmsd_valid_loss_history, rmsd_valid_acc_history, rmsd_valid_steps, rmsd_loss_history, rmsd_acc_history, rmsd_weights_history, rmsd_n_steps, rmsd_epoch_loss, rmsd_epoch_acc, rmsd_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

method = "adam"
epochs = 101
batch = 16
learningRate = 0.0001

adamd_valid_loss_history, adamd_valid_acc_history, adamd_valid_steps, adamd_loss_history, adamd_acc_history, adamd_weights_history, adamd_n_steps, adamd_epoch_loss, adamd_epoch_acc, adamd_epoch_weight = load_train_details(mainPath=mainPath,epochs=epochs,method=method, batch=batch, learningRate=learningRate )
epochs_array = np.array(list(range(epochs)))

# %%
def plot2x2(x,):
    figure, axis = plt.subplots(2, 2)
  
    axis[0, 0].plot(X, rmsa_valid_loss_history, label="rmsprop validation loss")  
    axis[0, 0].plot(X, adama_valid_loss_history, label="adam validation loss")
    axis[0, 0].plot(X, rmsa_epoch_loss, label="rmsprop epoch loss")
    axis[0, 0].plot(X, adama_epoch_loss, label="adam epoch loss")
    axis[0, 0].xlabel("epoch")
    axis[0, 0].ylabel("loss")
    axis[0, 0].set_title("")
    axis[0, 0].legend()
  
    axis[0, 1].plot(X, rmsb_valid_acc_history, label="rmsprop validation loss")  
    axis[0, 1].plot(X, adamb_valid_acc_history, label="adam validation loss")
    axis[0, 1].plot(X, rmsb_epoch_acc, label="rmsprop epoch loss")
    axis[0, 1].plot(X, adamb_epoch_acc, label="adam epoch loss")
    axis[0, 1].xlabel("epoch")
    axis[0, 1].ylabel("loss")
    axis[0, 1].set_title("")
    axis[0, 1].legend()
  
    axis[1, 0].plot(X, rmsc_valid_acc_history, label="rmsprop validation loss")  
    axis[1, 0].plot(X, adamc_valid_acc_history, label="adam validation loss")
    axis[1, 0].plot(X, rmsc_epoch_acc, label="rmsprop epoch loss")
    axis[1, 0].plot(X, adamc_epoch_acc, label="adam epoch loss")
    axis[1, 0].xlabel("epoch")
    axis[1, 0].ylabel("loss")
    axis[1, 0].set_title("")
    axis[1, 0].legend()

    axis[1, 1].plot(X, rmsd_valid_acc_history, label="rmsprop validation loss")  
    axis[1, 1].plot(X, adamd_valid_acc_history, label="adam validation loss")
    axis[1, 1].plot(X, rmsd_epoch_acc, label="rmsprop epoch loss")
    axis[1, 1].plot(X, adamd_epoch_acc, label="adam epoch loss")
    axis[1, 1].xlabel("epoch")
    axis[1, 1].ylabel("loss")
    axis[1, 1].set_title("")
    axis[1, 1].legend()

    # Combine all the operations and display
    plt.show()

# %%
X = epochs_array[-50:]
plt.figure(figsize=(8, 4))
plt.plot(X, rmsa_valid_loss_history[-50:], label="rmsprop validation loss")  
plt.plot(X, rmsa_epoch_loss[-50:], label="rmsprop epoch loss")
plt.plot(X, adama_valid_loss_history[-50:], label="adam validation loss")
plt.plot(X, adama_epoch_loss[-50:], label="adam epoch loss")
plt.xlabel('epochs')
# naming the y axis
plt.ylabel("loss")
  
# giving a title to my graph
plt.title("epoch 100, batch 32, lr 0.001")

# show a legend on the plot
plt.legend()
plt.savefig('loss-100,0.001,32.png', dpi=300)

# function to show the plot
plt.show()

# %%
X = epochs_array[-50:]
plt.figure(figsize=(8, 4))
plt.plot(X, rmsa_valid_acc_history[-50:], label="rmsprop validation acc")  
plt.plot(X, rmsa_epoch_acc[-50:], label="rmsprop epoch acc")
plt.plot(X, adama_valid_acc_history[-50:], label="adam validation acc")
plt.plot(X, adama_epoch_acc[-50:], label="adam epoch acc")
plt.xlabel('epochs')
# naming the y axis
plt.ylabel("loss")
  
# giving a title to my graph
plt.title("epoch 100, batch 32, lr 0.001")

# show a legend on the plot
plt.legend()
plt.savefig('acc-100,0.001,32.png', dpi=300)

# function to show the plot
plt.show()
